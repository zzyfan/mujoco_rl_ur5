# %% [markdown]
# # 参数学习笔记
#
# 这份笔记用来快速回答一个问题：每个参数到底控制什么。

# %%
import pandas as pd
from ur5_reach_config import ENV_PARAMETER_DOCS, TRAIN_PARAMETER_DOCS

env_df = pd.DataFrame(sorted(ENV_PARAMETER_DOCS.items()), columns=['name', 'meaning'])
train_df = pd.DataFrame(sorted(TRAIN_PARAMETER_DOCS.items()), columns=['name', 'meaning'])
env_df.head(), train_df.head()

# %% [markdown]
# ## 环境参数表

# %%
env_df

# %% [markdown]
# ## 训练参数表

# %%
train_df

# %% [markdown]
# ## 如何使用这份表
#
# - 先改环境参数，再看 `reset / step / reward`
# - 再改训练参数，再看 `build_model()`
# - 如果不知道一个参数有没有被某个算法用到，就回到 `train_ur5_reach.py` 搜索它的名字
