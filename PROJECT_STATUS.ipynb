# %% [markdown]
# # Project Status Notebook
#
# This notebook is a lightweight project handoff for `mujoco_ur5_rl`.
#
# - Main training line: `classic/`
# - Experimental line: `mjx/`
# - Supported robots: `ur5_cxy`, `zero_robotiq`

# %% [markdown]
# ## Current Completion
#
# The repository is in a usable state for the `classic/` pipeline.
#
# Verified items:
#
# - Python files compile successfully.
# - Gym environment registration works.
# - `classic.test` random-policy smoke test works with `--physics-backend mujoco`.
# - The default backend is now `mujoco`.
# - End-effector velocity defaults to finite-difference linear velocity.
# - Legacy zeroarm velocity behavior can still be enabled with `--legacy-zero-ee-velocity`.

# %% [markdown]
# ## Recommended Commands
#
# Smoke test:
#
# ```bash
# python -m classic.test --random-policy --episodes 1 --max-steps 10 --no-render
# ```
#
# Train:
#
# ```bash
# python classic/train.py --algo sac --robot ur5_cxy --run-name exp_sac --timesteps 500000 --device cuda --no-render
# ```
#
# Test:
#
# ```bash
# python classic/test.py --algo sac --robot ur5_cxy --run-name exp_sac --episodes 3 --render
# ```
#
# Reproduce zeroarm legacy end-effector velocity semantics:
#
# ```bash
# python classic/train.py --algo sac --robot zero_robotiq --run-name exp_zero_legacy --legacy-zero-ee-velocity --no-render
# ```

# %% [markdown]
# ## Notes
#
# - `classic/` is the recommended path for main experiments.
# - `mjx/` is kept for MuJoCo Playground and Warp experiments.
# - Large training artifacts should not be committed.
# - Keep `models/`, `logs/`, `models_mjx/`, and `logs_mjx/` out of version control.
